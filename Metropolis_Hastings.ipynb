# %% [markdown]
# <a href="https://colab.research.google.com/github/JazmineOrtizMarin/Simulaci-n-2/blob/main/Metropolis_Hastings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import random as rd
import numpy as np

# %%
def f(x):
 f = np.exp(-2*(x-2)**2)+.5*np.exp(-5*(x+2)**2)
 return f

# %%
xx=np.linspace(-5,5,100)
plt.plot(xx,f(xx))

# %%
def metropolis (N, x_0, q):
  a = []
  for i in range (N):
