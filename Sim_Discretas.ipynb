# %% [markdown]
# <a href="https://colab.research.google.com/github/JazmineOrtizMarin/Simulaci-n-2/blob/main/Sim_Discretas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import poisson
import random as rd
import math

# %%
mu = 4
k = 12

# %%
p = poisson.pmf (k, mu)
print ("P(k=12,mu=4) = ", p)
# Out:
# P(k=12,mu=4) =  0.00064151232441456

# %%
ks = range(0, 21) # Para la gráfica
pmf = poisson.pmf (ks, mu)

# %%
plt.figure()
plt.bar(ks, pmf)
plt.scatter([k],[p], s=80, zorder=3)
plt.title(f"Poisson(mu={mu})-P(k={k}) = {p:.10f})")
plt.xlabel("k")
plt.ylabel("P(K=k)")
plt.show()

# %%
# Parámetros
lmbd = 4
T = 5

# %%
# Inicialización
t = 0
N = 0
S = [] # Tiempos de arribo

# %%
while True:
  U = rd.random()
  t = t - (math.log(U) / lmbd)
  if t > T:
    break
  N += 1
  S.append (t)

# %%
print("Número de llegadas N(T) = ", N)
print("Número de llegada S = ", S)
# Out:
# Número de llegadas N(T) =  20
# Número de llegada S =  [0.03603790579778444, 0.479529872954063, 0.5544980261960244, 0.8236262120971839, 0.9286659352145595, 0.9442494562211536, 1.19294405165909, 1.957160444702858, 2.067426795040806, 2.4272202551848654, 2.6014085778962657, 2.6881586127479693, 2.8878316884304596, 3.353010857811428, 3.6671545632071902, 3.82728125391914, 4.384531919286389, 4.388367171541025, 4.805117704882443, 4.9734888853166765]

# %%
plt.step([0] + S + [T], list(range(0,N+1))+[N], where='post')
plt.title(f"Proceso de Poisson Homogéneo (λ={lmbd},T={T})")
plt.xlabel("Tiempo")
plt.ylabel("Número de llegadas N(t)")
#plt.grid(True)
plt.show()
